# %%
import json
import os
import re
from CorpusStat import CorpusStat
from SumCollector import SumCollector

summary_pattern = r'summary{{(.*)}}'
text_pattern = r'text{{(.*)}}'

data_path = '/search/odin/data/summarization_data/'

dealed_news_2016_train = data_path + 'news2014-2016zh/dealed_news_2016/dealed_corpus_news2016_train'
dealed_news_2016_test = data_path + 'news2014-2016zh/dealed_news_2016/dealed_corpus_news2016_test'
dealed_news_2016_valid = data_path + 'news2014-2016zh/dealed_news_2016/dealed_corpus_news2016_valid'

news2016zh_train = data_path +'zh_data/news2016zh_train.json'

chinese_abstractive_corpus_path = data_path + 'chinese_abstractive_corpus/copus/'

nlpcc_2018_train = data_path + 'TTNewsCorpus_NLPCC2018/toutiao4nlpcc/train_with_summ.txt'

collector1k = SumCollector(1000)
collector5k = SumCollector(5000)
collector10k = SumCollector(10000)

collectors = [collector1k, collector5k, collector10k]

stat = CorpusStat()

# %%
print("fetching dataset: dealed_news_2016_train")
stat.clear()
with open(dealed_news_2016_train, 'r', encoding='utf-8') as file:
    lines = file.readlines()
    for line in lines:
        if(stat.text_stat[0] == 0):
            print(line)
        jsonline = json.loads(line)
        # print(jsonline)
        stat.stat_once(jsonline["abstract"], jsonline["document"])
        for collector in collectors:
            collector.add_summ_pair(jsonline["abstract"], jsonline["document"])
    stat.print_all()
# Out:
# fetching dataset: dealed_news_2016_train
# {"abstract": "福利院改造家属担心老人无处安置", "document": "福利院正在装修市民：东湖区社会福利院装修要老人搬走院方：不会强制老人离开，安置方案还在商讨本报讯记者陈青青文聂俊鹏图近日，记者接到东湖区社会福利院在住老人家属的电话，说该养老院计划从5月份开始大规模建筑改造，要求所有老人搬离养老院，并且改造提升之后的收费会大幅增加，让很多家属担心老人日后的生活。家属：担心老人今后去留东湖区社会福利院在住老人的家属胡先生说，他的母亲已经快90岁了，有些老年痴呆，生活不能自理。家里几个兄弟姐妹因为工作无暇照顾，便把老人送进养老院。“公立的养老院价钱比较公道，每个月只要1600元就有专业护士看护。而且该福利院位置好，交通方便，一家人时不时会来陪陪老人。现在说要装修，要求家属5月初把老人领出养老院，只给一个月的时间，我们也找不到合适的地方照顾老母亲。”另一位家属张女士也表示，福利院要把这么多老人遣散回家，很多人家里照顾老人都有困难。不知道什么时候养老院才能重新运营。“有工作人员说保守估计工程也要半年的时间，听说改造之后老人入院的价格要增加一千多，预计在2300-2600元。如果公立私立养老院的价格都差不多了，宁可多出钱去私立的。”民政局：不知道该院要“大动工”24号，记者就此事致电东湖区社会福利处熊处长。熊处长表示该福利院的院长曾经提起过养老院设备陈旧，并且不符合新的消防规定，且想要引进一些医疗设备，所以需要进行部分改造。他们考察该养老院确实有改造需求，同意局部改造。但是并不知道养老院要“大动工”，熊处长表示如果因为改造要让养老院所有老人短时间内出院是不现实的，对于该养老院酝酿装修后大幅度提价的问题熊处长也表示毫不知情。他将东湖区社会福利院负责人张院长的电话给了记者，让记者找院长核实情况。记者随后到养老院进行走访，发现该院2楼中栋已经开始装修，楼内已经没人居住。经询问记者得知，这栋楼也已经施工几个月了，改造工程的完工时间尚不能确定。一罗姓护工向记者表示，还有一个月，她们就要再找别的养老院工作了，福利院要装修大半年。而关于装修后养老院提价的问题，该护工说：“现在私立养老院价格都很高，东湖养老院提升设施之后也会涨价的，按照行情，应该会涨1200左右。”院长：安置方案还在商讨记者随后联系到了该院的负责人张院长。张院长说，确实在上周召开了关于改造养老院的会议，但是关于安置老人的方案并没有最后敲定。张院长称，开会时他本人并不在场，现在也已经安排了一些干部和护工及家属们沟通解释。现在初步的方案是以局部改造为主，最好是能分批进行整体修缮，尽量让老人们不离院。如果不能对建筑物分批改造，确实需要清空养老院，也会对老人和护工们进行安置，不会因为改造而遣散任何一名护工，可能会选择把老人们暂时分散安置到各个兄弟养老院，由原先的护工进行看护。张院长也承认，将老人全数安排到其他养老院确有困难，对于生活能自理，并且家属愿意暂时接回家照顾的，他们也希望能把老人暂时接回家，但不会强制家属把老人领走。最后，如果还不能解决场地和人员的矛盾，他们会另行租赁一个新场地，全院暂时搬迁过去。至于涨价，原则上来说肯定不会涨得那么离谱，“可能就涨几百块钱。总之，最后拿出的方案一定会让老人和家属们满意。”", "blod": []}
#
# ---------------average length --------------
# summary: 19.866345
# text: 555.835684
# -----------------------max min length --------------
# max text length: 329550
# min text length: 50
# ----------------------text number statistics ---------------
# 0+:	322787	100.00
# 1000+:	39283	12.17
# 2000+:	7174	2.22
# 3000+:	2728	0.85
# 4000+:	1511	0.47
# 5000+:	914	0.28
# 6000+:	643	0.20
# 7000+:	455	0.14
# 8000+:	357	0.11
# 9000+:	284	0.09
# 10000+:	166	0.05
# 11000+:	127	0.04
# 12000+:	96	0.03
# 13000+:	68	0.02
# 14000+:	51	0.02
# 15000+:	39	0.01
# 16000+:	35	0.01
# 17000+:	27	0.01
# 18000+:	23	0.01
# 19000+:	20	0.01
# 20000+:	20	0.01

# %%
print("fetching dataset: news2016zh_train")
stat.clear()
with open(news2016zh_train, 'r', encoding='utf-8') as file:
    lines = file.readlines()
    for line in lines:
        if(stat.text_stat[0] == 0):
            print(line)
        jsonline = json.loads(line.strip())
        # print(jsonline)
        stat.stat_once(jsonline["title"], jsonline["content"])
        for collector in collectors:
            collector.add_summ_pair(jsonline["title"], jsonline["content"])
    stat.print_all()
# Out:
# fetching dataset: news2016zh_train
# {"news_id": "411086456", "keywords": "英国石油公司发现巨型油田 股价飙升3倍！", "desc": "英国石油天然气投资公司(UKOG)9日说，英格兰南部地底探测到规模巨大的油田，石油储量或许高达1000亿桶。这家公司的首席执行官史蒂芬·桑德", "title": "英国石油公司发现巨型油田 股价飙升3倍！", "source": "移动中金在线", "time": "04-10 15:15", "content": "英国石油天然气投资公司(UKOG)9日说，英格兰南部地底探测到规模巨大的油田，石油储量或许高达1000亿桶。这家公司的首席执行官史蒂芬·桑德森当天在接受英国媒体采访时表示，该公司认为英格兰南部地区地底储有巨量的石油资源，推测储量在500亿至1000亿桶之间，或许是英国过去30年来发现的最大陆上石油资源。这可是一个惊人的数字。要知道，苏格兰在北海的所有石油公司在过去40年的总产量也只有450亿桶。该公司预计，这些石油资源地下储存深度在2500英尺至3000英尺(762米至914米)之间，其中可以开发的比例为5%至15%，这意味着到2030年，这一地区的石油产量将能够满足英国10%至30%的石油需求。英格兰南部的石油开采活动已有数十年历史，开采地点分布在肯特郡、苏赛克斯郡、萨里郡和汉普郡等地。去年，英国地质勘探局曾发布报告称，英格兰南部地区拥有页岩油资源，储量约为22亿至85亿桶。这一爆炸性的公告发布后，UKOG的股票便开始疯涨。截至4月9日，UKOG的股价从原先的每股1.1便士一路狂飙至3.25便士，涨幅高达261.99%，最高价甚至冲到了4.7便士。股票市值瞬间飙升为原先的3倍，达到1822万英镑。"}
#
# ---------------average length --------------
# summary: 20.009294
# text: 1157.991989
# -----------------------max min length --------------
# max text length: 356749
# min text length: 0
# ----------------------text number statistics ---------------
# 0+:	2430752	100.00
# 1000+:	974678	40.10
# 2000+:	348287	14.33
# 3000+:	148033	6.09
# 4000+:	78555	3.23
# 5000+:	47205	1.94
# 6000+:	31041	1.28
# 7000+:	22290	0.92
# 8000+:	16937	0.70
# 9000+:	13547	0.56
# 10000+:	10656	0.44
# 11000+:	8577	0.35
# 12000+:	6792	0.28
# 13000+:	5420	0.22
# 14000+:	4338	0.18
# 15000+:	3409	0.14
# 16000+:	2709	0.11
# 17000+:	2140	0.09
# 18000+:	1726	0.07
# 19000+:	1402	0.06
# 20000+:	1123	0.05

# %%
print("fetching dataset: Chinese Abstractive Corpus")
file_list = os.listdir(chinese_abstractive_corpus_path)
stat.clear()
for filename in file_list:
    with open(chinese_abstractive_corpus_path + filename, 'r', encoding="utf-8") as file:
        file_lines = file.readlines()
        if(stat.text_stat[0] == 0):
            print(file_lines)
        raw_summary = file_lines[0]
        raw_text = file_lines[1]

        summary = re.match(summary_pattern, raw_summary).group(1)
        text = re.match(text_pattern, raw_text).group(1)
        stat.stat_once(summary, text)
        for collector in collectors:
            collector.add_summ_pair(summary, text)

stat.print_all()
# Out:
# fetching dataset: Chinese Abstractive Corpus
# ['summary{{在线少儿外教机构们的生存空间越来越小了。}}\n', 'text{{摘要：在线少儿外教机构们的生存空间越来越小了。鲸媒体讯（文/宛青）9月7日，在线少儿英语品牌VIPKID透露，公司内部已经成立独立的“[小班课](http://www.jingmeiti.com/archives/tag/%e5%b0%8f%e7%8f%ad%e8%af%be"浏览关于“小班课”的文章")”事业部，运营1对多模式的在线少儿英语产品。二期该项目[孵化](http://www.jingmeiti.com/archives/tag/%e5%ad%b5%e5%8c%96"浏览关于“孵化”的文章")接近一年时间，试运营接近半年时间，8月份营收突破1000万元。据透露， **“小班课”独立事业部员工数量已经超过100人，很多核心成员均来自英孚教育。**负责人王冠2011年曾在英孚教育负责全球在线英语学习产品，2015年入驻创新工场参与创业孵化，曾帮助VIPKID规划产品架构，2016年9月正式加入VIPKID负责1对多项目。师资负责人王顺熹此前也在英孚教育负责外教招聘工作。资料称，与VIPKID主营的1对1授课模式相比，**该小班课项目采用1对4在线授课模式，以及同样100%浸入式英语课堂，每节课约40分钟；课程为3个级别，面向不同年龄的少儿，强调互动和参与，由VIPKID与国家地理学习OurWorld以及Cengage国家地理学习共同研发。**![](http://www.jingmeiti.com/wp-content/uploads/2017/09/2017090709440624.png)**而从产品界面看，“小班课” 1对多产品并没有采用VIPKID的橙色主基调，而是绿色元素为主，预计未来会以独立品牌形式运营。**外教的头像出现在屏幕左上方，由他调动每个学生参与互动和教学环节。据内部人士透露，上课的4个孩子并非随机选择，而是通过大数据匹配英语水平最相似的学员，从而保证学习效果。据透露，VIPKID创始人米雯娟对于这个项目寄予很大希望，她认为这是帮助VIPKID覆盖全球更大范围的儿童群体的重要学习平台。此前，VIPKID对内部孵化1对多产品一直持保密态度，很少对外透露相关详情。目前来看，该产品距离正式发布的时间可能不会太久。8月23日，VIPKID推出了少儿中文学习平台Lingobus，还获得了由红杉、腾讯领投的2亿美元D轮融资。几日前，VIPKID宣布8月31日的单日营收突破6500万。今年暑假，VIPKID曾宣布7月单月收入突破4亿，全年营收预计达50亿元。在线少儿[一对一](http://www.jingmeiti.com/archives/tag/%e4%b8%80%e5%af%b9%e4%b8%80"浏览关于“一对一”的文章")的竞争早已白热化，而如今似乎小班课市场的争夺也愈演愈烈。今年以来，魔力耳朵、金沃斯、abc360旗下兰迪学科英语等等主打1对多的在线少儿英语机构纷纷获得融资，此次一对一的“巨头”入局小班课，未来行业格局又将如何？}}']
# ---------------average length --------------
# summary: 53.084491
# text: 2356.007681
# -----------------------max min length --------------
# max text length: 141371
# min text length: 3
# ----------------------text number statistics ---------------
# 0+:	24476	100.00
# 1000+:	18941	77.39
# 2000+:	10545	43.08
# 3000+:	6130	25.04
# 4000+:	3697	15.10
# 5000+:	2212	9.04
# 6000+:	1335	5.45
# 7000+:	767	3.13
# 8000+:	459	1.88
# 9000+:	292	1.19
# 10000+:	194	0.79
# 11000+:	127	0.52
# 12000+:	95	0.39
# 13000+:	69	0.28
# 14000+:	49	0.20
# 15000+:	33	0.13
# 16000+:	26	0.11
# 17000+:	23	0.09
# 18000+:	20	0.08
# 19000+:	17	0.07
# 20000+:	15	0.06

# %%
print("fetching dataset: NLPCC 2018 train")
stat.clear()
with open(nlpcc_2018_train) as file:
    line = file.readline().strip('\r\n')
    while line:
        jsonline = json.loads(line)
        stat.stat_once(jsonline["summarization"], jsonline["article"])
        for collector in collectors:
            collector.add_summ_pair(jsonline["summarization"], jsonline["article"])
        line = file.readline().strip('\r\n')
stat.print_all()
# Out:
# fetching dataset: NLPCC 2018 train
# ---------------average length --------------
# summary: 45.065440
# text: 1036.160260
# -----------------------max min length --------------
# max text length: 40488
# min text length: 101
# ----------------------text number statistics ---------------
# 0+:	50000	100.00
# 1000+:	17735	35.47
# 2000+:	5940	11.88
# 3000+:	2190	4.38
# 4000+:	1027	2.05
# 5000+:	548	1.10
# 6000+:	329	0.66
# 7000+:	181	0.36
# 8000+:	117	0.23
# 9000+:	83	0.17
# 10000+:	65	0.13
# 11000+:	45	0.09
# 12000+:	40	0.08
# 13000+:	34	0.07
# 14000+:	26	0.05
# 15000+:	21	0.04
# 16000+:	18	0.04
# 17000+:	16	0.03
# 18000+:	15	0.03
# 19000+:	15	0.03
# 20000+:	15	0.03

# %%
for collector in collectors:
    collector.print_stats()
# Out:
# ---------------average length --------------
# summary: 21.574911
# text: 2193.973984
# -----------------------max min length --------------
# max text length: 356749
# min text length: 1000
# ----------------------text number statistics ---------------
# 0+:	1050637	100.00
# 1000+:	1050637	100.00
# 2000+:	371946	35.40
# 3000+:	159081	15.14
# 4000+:	84790	8.07
# 5000+:	50879	4.84
# 6000+:	33348	3.17
# 7000+:	23693	2.26
# 8000+:	17870	1.70
# 9000+:	14206	1.35
# 10000+:	11081	1.05
# 11000+:	8876	0.84
# 12000+:	7023	0.67
# 13000+:	5591	0.53
# 14000+:	4464	0.42
# 15000+:	3502	0.33
# 16000+:	2788	0.27
# 17000+:	2206	0.21
# 18000+:	1784	0.17
# 19000+:	1454	0.14
# 20000+:	1173	0.11
# ---------------average length --------------
# summary: 22.648834
# text: 8621.329606
# -----------------------max min length --------------
# max text length: 356749
# min text length: 5000
# ----------------------text number statistics ---------------
# 0+:	50879	100.00
# 1000+:	50879	100.00
# 2000+:	50879	100.00
# 3000+:	50879	100.00
# 4000+:	50879	100.00
# 5000+:	50879	100.00
# 6000+:	33348	65.54
# 7000+:	23693	46.57
# 8000+:	17870	35.12
# 9000+:	14206	27.92
# 10000+:	11081	21.78
# 11000+:	8876	17.45
# 12000+:	7023	13.80
# 13000+:	5591	10.99
# 14000+:	4464	8.77
# 15000+:	3502	6.88
# 16000+:	2788	5.48
# 17000+:	2206	4.34
# 18000+:	1784	3.51
# 19000+:	1454	2.86
# 20000+:	1173	2.31
# ---------------average length --------------
# summary: 22.068766
# text: 15962.217580
# -----------------------max min length --------------
# max text length: 356749
# min text length: 10000
# ----------------------text number statistics ---------------
# 0+:	11081	100.00
# 1000+:	11081	100.00
# 2000+:	11081	100.00
# 3000+:	11081	100.00
# 4000+:	11081	100.00
# 5000+:	11081	100.00
# 6000+:	11081	100.00
# 7000+:	11081	100.00
# 8000+:	11081	100.00
# 9000+:	11081	100.00
# 10000+:	11081	100.00
# 11000+:	8876	80.10
# 12000+:	7023	63.38
# 13000+:	5591	50.46
# 14000+:	4464	40.29
# 15000+:	3502	31.60
# 16000+:	2788	25.16
# 17000+:	2206	19.91
# 18000+:	1784	16.10
# 19000+:	1454	13.12
# 20000+:	1173	10.59

# %%
collector1k.dump_data(data_path + "custom_data/integrated_train_data_1k")
collector5k.dump_data(data_path + "custom_data/integrated_train_data_5k")
collector10k.dump_data(data_path + "custom_data/integrated_train_data_10k")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-48d982398ebc> in <module>
# ----> 1 collector1k.dump_data(data_path + "custom_data/integrated_train_data_1k")
#       2 collector5k.dump_data(data_path + "custom_data/integrated_train_data_5k")
#       3 collector10k.dump_data(data_path + "custom_data/integrated_train_data_10k")
#
# ~/code/SumCollector.py in dump_data(self, path)
#      42
#      43     def dump_data(self, path):
# ---> 44         with open(path, 'w', encoding="utf-8") as file:
#      45             print("writing into file: " + path)
#      46             start = time.clock()
#
# PermissionError: [Errno 13] Permission denied: '/search/odin/data/summarization_data/custom_data/integrated_train_data_1k'
